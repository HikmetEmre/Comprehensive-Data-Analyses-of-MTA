# %%
### TRYING TO FIND OPTIMUM CIRCUMSTANCES("TIME RANGE, PLACE,DATE..") FOR SELLING TICKETS###

### For discovering to optimum circumstances we gonna use datasets which are related with newyork city.###

### Those datasets are ("MTA ENTRY AND EXIT","NYC TAXI ZONE LOOKUP","")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("./taxi_zone_lookup.csv")

# %%
df
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                       NV          NaN
# 264         265        Unknown                      NaN          NaN
#
# [265 rows x 4 columns]

# %%
df.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                       NV          NaN
# 264         265        Unknown                      NaN          NaN
#
# [265 rows x 4 columns]>

# %%
df.isnull().sum()
# Out:
# LocationID      0
# Borough         0
# Zone            1
# service_zone    2
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <AxesSubplot: >

# %%
sns.set_style("whitegrid")
sns.countplot(y="Borough",data=df,order=df.value_counts("Borough").index);
plt.title("Taxi Zone Lookup")
plt.savefig("graphs/taxi_zone.png",bbox_inches='tight')

# %%
df2=pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_210925.txt")

# %%
df.value_counts()
# Out:
# LocationID  Borough    Zone                       service_zone
# 1           EWR        Newark Airport             EWR             1
# 166         Manhattan  Morningside Heights        Boro Zone       1
# 168         Bronx      Mott Haven/Port Morris     Boro Zone       1
# 169         Bronx      Mount Hope                 Boro Zone       1
# 170         Manhattan  Murray Hill                Yellow Zone     1
#                                                                  ..
# 94          Bronx      Fordham South              Boro Zone       1
# 95          Queens     Forest Hills               Boro Zone       1
# 96          Queens     Forest Park/Highland Park  Boro Zone       1
# 97          Brooklyn   Fort Greene                Boro Zone       1
# 263         Manhattan  Yorkville West             Yellow Zone     1
# Length: 263, dtype: int64

# %%
df2
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  09/18/2021
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  09/18/2021
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  09/18/2021
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  09/18/2021
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  09/18/2021
# ...       ...   ...       ...            ...      ...      ...         ...
# 210395  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/24/2021
# 210396  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/24/2021
# 210397  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/24/2021
# 210398  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/24/2021
# 210399  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/24/2021
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210400 entries, 0 to 210399
# Data columns (total 11 columns):
#  #   Column                                                                Non-Null Count   Dtype
# ---  ------                                                                --------------   -----
#  0   C/A                                                                   210400 non-null  object
#  1   UNIT                                                                  210400 non-null  object
#  2   SCP                                                                   210400 non-null  object
#  3   STATION                                                               210400 non-null  object
#  4   LINENAME                                                              210400 non-null  object
#  5   DIVISION                                                              210400 non-null  object
# ...

# %%
sns.heatmap(df2.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <AxesSubplot: >

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210400 entries, 0 to 210399
# Data columns (total 11 columns):
#  #   Column                                                                Non-Null Count   Dtype
# ---  ------                                                                --------------   -----
#  0   C/A                                                                   210400 non-null  object
#  1   UNIT                                                                  210400 non-null  object
#  2   SCP                                                                   210400 non-null  object
#  3   STATION                                                               210400 non-null  object
#  4   LINENAME                                                              210400 non-null  object
#  5   DIVISION                                                              210400 non-null  object
# ...

# %%
df2.isnull().sum()
# Out:
# C/A                                                                     0
# UNIT                                                                    0
# SCP                                                                     0
# STATION                                                                 0
# LINENAME                                                                0
# DIVISION                                                                0
# DATE                                                                    0
# TIME                                                                    0
# DESC                                                                    0
# ENTRIES                                                                 0
# EXITS                                                                   0
# dtype: int64

# %%
df_est=pd.read_csv("./MTA_Daily_Ridership_Data__Beginning_2020.csv")

# %%
df_est.head()
# Out:
#          Date  Subways: Total Estimated Ridership  \
# 0  11/22/2022                             3548878
# 1  11/21/2022                             3366444
# 2  11/20/2022                             1720204
# 3  11/19/2022                             2320286
# 4  11/18/2022                             3539383
#
#    Subways: % of Comparable Pre-Pandemic Day  \
# 0                                      0.608
# 1                                      0.588
# 2                                      0.763
# 3                                      0.727
# 4                                      0.610
#
#    Buses: Total Estimated Ridership  Buses: % of Comparable Pre-Pandemic Day  \
# 0                           1236503                                    0.537
# 1                           1308734                                    0.576
# 2                            613770                                    0.659
# ...

# %%
df_est.isnull().sum()
# Out:
# Date                                                               0
# Subways: Total Estimated Ridership                                 0
# Subways: % of Comparable Pre-Pandemic Day                          0
# Buses: Total Estimated Ridership                                   0
# Buses: % of Comparable Pre-Pandemic Day                            0
# LIRR: Total Estimated Ridership                                   31
# LIRR: % of 2019 Monthly Weekday/Saturday/Sunday Average           31
# Metro-North: Total Estimated Ridership                            32
# Metro-North: % of 2019 Monthly Weekday/Saturday/Sunday Average    32
# Access-A-Ride: Total Scheduled Trips                               2
# Access-A-Ride: % of Comprable Pre-Pandemic Day                     2
# Bridges and Tunnels: Total Traffic                                 0
# Bridges and Tunnels: % of Comparable Pre-Pandemic Day              0
# dtype: int64

# %%
sns.heatmap(df_est.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <AxesSubplot: >

# %%
df_est.rename(columns={"Subways: Total Estimated Ridership":"SubwayTER"},inplace=True)
df_est.rename(columns={"Buses: Total Estimated Ridership":"BusTER"},inplace=True)
df_est.rename(columns={"LIRR: Total Estimated Ridership":"LIRRTER"},inplace=True)
df_est.rename(columns={"Metro-North: Total Estimated Ridership":"MetroNorthTeR"},inplace=True)
df_est.rename(columns={"Bridges and Tunnels: Total Traffic":"Bridges_Tunnels_TT"},inplace=True)

# %%
df_est.head()
# Out:
#          Date  SubwayTER  Subways: % of Comparable Pre-Pandemic Day   BusTER  \
# 0  11/22/2022    3548878                                      0.608  1236503
# 1  11/21/2022    3366444                                      0.588  1308734
# 2  11/20/2022    1720204                                      0.763   613770
# 3  11/19/2022    2320286                                      0.727   821154
# 4  11/18/2022    3539383                                      0.610  1354177
#
#    Buses: % of Comparable Pre-Pandemic Day   LIRRTER  \
# 0                                    0.537  200300.0
# 1                                    0.576  185600.0
# 2                                    0.659   74500.0
# 3                                    0.605   97700.0
# 4                                    0.618  183600.0
#
#    LIRR: % of 2019 Monthly Weekday/Saturday/Sunday Average  MetroNorthTeR  \
# 0                                               0.69             183800.0
# ...

# %%
df_est.drop
# Out:
# <bound method DataFrame.drop of            Date  SubwayTER  Subways: % of Comparable Pre-Pandemic Day  \
# 0    11/22/2022    3548878                                      0.608
# 1    11/21/2022    3366444                                      0.588
# 2    11/20/2022    1720204                                      0.763
# 3    11/19/2022    2320286                                      0.727
# 4    11/18/2022    3539383                                      0.610
# ..          ...        ...                                        ...
# 992  03/05/2020    5513656                                      0.956
# 993  03/04/2020    5515945                                      0.968
# 994  03/03/2020    5498556                                      0.961
# 995  03/02/2020    5347055                                      1.239
# 996  03/01/2020    2214601                                      0.987
#
#       BusTER  Buses: % of Comparable Pre-Pandemic Day   LIRRTER  \
# ...

# %%
df_est.loc[(df_est.SubwayTER>300000)&(df_est.BusTER>1350000)&(df_est.Date>="2022-05-01")&(df_est.Date<="2022-06-15")]
# Out:
# Empty DataFrame
# Columns: [Date, SubwayTER, Subways: % of Comparable Pre-Pandemic Day, BusTER, Buses: % of Comparable Pre-Pandemic Day, LIRRTER, LIRR: % of 2019 Monthly Weekday/Saturday/Sunday Average, MetroNorthTeR, Metro-North: % of 2019 Monthly Weekday/Saturday/Sunday Average, Access-A-Ride: Total Scheduled Trips, Access-A-Ride: % of Comprable Pre-Pandemic Day, Bridges_Tunnels_TT, Bridges and Tunnels: % of Comparable Pre-Pandemic Day]
# Index: []

# %%
df_est["Date"]=df_est["Date"].astype("datetime64[ns]")
df_est["Date"] = pd.to_datetime(df_est["Date"], format='%Y-%m-%d')

# %%
df_est.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997 entries, 0 to 996
# Data columns (total 13 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Date                                                            997 non-null    datetime64[ns]
#  1   SubwayTER                                                       997 non-null    int64
#  2   Subways: % of Comparable Pre-Pandemic Day                       997 non-null    float64
#  3   BusTER                                                          997 non-null    int64
#  4   Buses: % of Comparable Pre-Pandemic Day                         997 non-null    float64
#  5   LIRRTER                                                         966 non-null    float64
#  6   LIRR: % of 2019 Monthly Weekday/Saturday/Sunday Average         966 non-null    float64
# ...

# %%
event_list=pd.read_csv("NYC_Permitted_Event_Information.csv")

# %%
event_list.head()
# Out:
#    Event ID                    Event Name         Start Date/Time  \
# 0    680389  Menorah Display and Lighting  12/19/2022 08:00:00 AM
# 1    674336       Soccer - Non Regulation  12/21/2022 08:00:00 PM
# 2    673434            Soccer -Regulation  01/06/2023 12:00:00 PM
# 3    668629        Covid -19 testing site  12/29/2022 07:00:00 AM
# 4    680038                   Celebration  01/13/2023 11:00:00 AM
#
#             End Date/Time      Event Agency     Event Type  Event Borough  \
# 0  12/19/2022 08:00:00 PM  Parks Department  Special Event      Manhattan
# 1  12/21/2022 10:00:00 PM  Parks Department  Sport - Adult       Brooklyn
# 2  01/06/2023 02:00:00 PM  Parks Department  Sport - Adult      Manhattan
# 3  12/29/2022 07:00:00 PM  Parks Department  Special Event  Staten Island
# 4  01/13/2023 01:00:00 PM  Parks Department  Special Event      Manhattan
#
#                                       Event Location Event Street Side  \
# ...

# %%
event_list.info
# Out:
# <bound method DataFrame.info of       Event ID                    Event Name         Start Date/Time  \
# 0       680389  Menorah Display and Lighting  12/19/2022 08:00:00 AM
# 1       674336       Soccer - Non Regulation  12/21/2022 08:00:00 PM
# 2       673434            Soccer -Regulation  01/06/2023 12:00:00 PM
# 3       668629        Covid -19 testing site  12/29/2022 07:00:00 AM
# 4       680038                   Celebration  01/13/2023 11:00:00 AM
# ...        ...                           ...                     ...
# 8154    637519                   Celebration  12/17/2022 11:00:00 AM
# 8155    674811                   Celebration  12/18/2022 10:00:00 AM
# 8156    669847                   Celebration  12/29/2022 11:00:00 AM
# 8157    669720                   Celebration  12/18/2022 10:00:00 AM
# 8158    674746                   Celebration  12/31/2022 03:00:00 PM
#
#                End Date/Time      Event Agency     Event Type  Event Borough  \
# ...

# %%
sns.heatmap(event_list.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <AxesSubplot: >

# %%
event_list.dropna(subset=["Street Closure Type","Event Street Side","Police Precinct","Community Board","Event Agency","Event Street Side","Street Closure Type"],inplace=True)

# %%
event_list.head()
# Out:
#      Event ID                                         Event Name  \
# 29     675984                               Chanukah Celebration
# 52     617412  Union Square Greenmarket Monday, Wednesday, Fr...
# 66     672396                      Chanukah Ice Sculpted Menorah
# 125    611894          East Harlem Health Action center Food Box
# 147    610466                        Inwood Greenmarket Saturday
#
#             Start Date/Time           End Date/Time  \
# 29   12/18/2022 06:00:00 PM  12/18/2022 08:00:00 PM
# 52   12/16/2022 08:00:00 AM  12/16/2022 07:00:00 PM
# 66   12/19/2022 04:30:00 PM  12/19/2022 08:30:00 PM
# 125  12/22/2022 01:30:00 PM  12/22/2022 06:30:00 PM
# 147  12/24/2022 08:00:00 AM  12/24/2022 05:00:00 PM
#
#                       Event Agency       Event Type Event Borough  \
# 29   Street Activity Permit Office  Religious Event     Manhattan
# 52   Street Activity Permit Office   Farmers Market     Manhattan
# ...

# %%
del event_list["Community Board"]
del event_list["Event Agency"]
del event_list["Event Street Side"]

# %%
event_list.set_index('Event Name').filter(like='S', axis=0)
# Out:
#                                                     Event ID  \
# Event Name
# Union Square Greenmarket Monday, Wednesday, Fri...    617412
# Chanukah Ice Sculpted Menorah                         672396
# Inwood Greenmarket Saturday                           610466
# West Side Campaign Against Hunger Food Pantry         685726
# West Side Campaign Against Hunger Food Pantry         685726
# ...                                                      ...
# West Side Campaign Against Hunger Food Pantry         685726
# West Side Campaign Against Hunger Food Pantry         685726
# West Side Campaign Against Hunger Food Pantry         685726
# CIPRIANI NEW YEARS EVE EVENT                          685560
# West Side Campaign Against Hunger Food Pantry         685726
#
#                                                            Start Date/Time  \
# Event Name
# Union Square Greenmarket Monday, Wednesday, Fri...  12/16/2022 08:00:00 AM
# ...

# %%
event_list.head()
# Out:
#      Event ID                                         Event Name  \
# 29     675984                               Chanukah Celebration
# 52     617412  Union Square Greenmarket Monday, Wednesday, Fr...
# 66     672396                      Chanukah Ice Sculpted Menorah
# 125    611894          East Harlem Health Action center Food Box
# 147    610466                        Inwood Greenmarket Saturday
#
#             Start Date/Time           End Date/Time       Event Type  \
# 29   12/18/2022 06:00:00 PM  12/18/2022 08:00:00 PM  Religious Event
# 52   12/16/2022 08:00:00 AM  12/16/2022 07:00:00 PM   Farmers Market
# 66   12/19/2022 04:30:00 PM  12/19/2022 08:30:00 PM  Religious Event
# 125  12/22/2022 01:30:00 PM  12/22/2022 06:30:00 PM   Farmers Market
# 147  12/24/2022 08:00:00 AM  12/24/2022 05:00:00 PM   Farmers Market
#
#     Event Borough                                     Event Location  \
# 29      Manhattan     EAST   93 STREET between 1 AVENUE and 2 AVENUE
# ...

# %%
sns.set_style("whitegrid")
sns.countplot(y="Event Borough",data=event_list,order=event_list.value_counts("Event Borough").index);
plt.title("Event Zones Analysis")
plt.savefig("graphs/event_zone.png",bbox_inches='tight')

# %%
sns.set_style("whitegrid")
sns.countplot(y="Event Type",data=event_list,order=event_list.value_counts("Event Type").index);
plt.title("Event Type Analysis")
plt.savefig("graphs/event_type.png",bbox_inches='tight')

# %%
tech_event_data= {'Event_Name': ['DigiMarCon East ', 'TECHSPO New York', 'Empire FinTech Conference ', 'FinTech Nexus '],
        'Event_Date': ["04-20-2023", "04-21-2023", "04-26-2023", "05-10-2023"],
         "Event_Location":["New York Marriott Brooklyn Bridge Hotel","New York Marriott Brooklyn Bridge Hotel","New World Stages 340 W 50th Street","Javits Center Manhattan"] }

# %%
df_tech_event=pd.DataFrame(tech_event_data,index=["First Event","Second Event","Third Event","Fourth Event"])

# %%
df_tech_event
# Out:
#                               Event_Name  Event_Date  \
# First Event             DigiMarCon East   04-20-2023
# Second Event            TECHSPO New York  04-21-2023
# Third Event   Empire FinTech Conference   04-26-2023
# Fourth Event              FinTech Nexus   05-10-2023
#
#                                        Event_Location
# First Event   New York Marriott Brooklyn Bridge Hotel
# Second Event  New York Marriott Brooklyn Bridge Hotel
# Third Event        New World Stages 340 W 50th Street
# Fourth Event                  Javits Center Manhattan

# %%
teschpo_visitors={"Event Year":["2017","2018","2019","2020","2021","2022","2023"],
                 "Event_Date":["05-17-2017","05-20-2018","05-19-2019","05-18-2020","04-22-2021","04-06-2022","04-21-2023"],
                 "Total Visitors":[19821,23744,24167,16595,18413,19480,20500]}

# %%
df_techspo=pd.DataFrame(teschpo_visitors,index=[1,2,3,4,5,6,7])

# %%
df_techspo
# Out:
#   Event Year  Event_Date  Total Visitors
# 1       2017  05-17-2017           19821
# 2       2018  05-20-2018           23744
# 3       2019  05-19-2019           24167
# 4       2020  05-18-2020           16595
# 5       2021  04-22-2021           18413
# 6       2022  04-06-2022           19480
# 7       2023  04-21-2023           20500

# %%
sns.set_style("whitegrid")
plt.bar(df_techspo["Event Year"],df_techspo["Total Visitors"])
plt.xlabel("Event Year")
plt.ylabel("Total Visitors")
plt.title("Yearly Visitors To TECHSPO")
plt.savefig("graphs/techspo.png",bbox_inches='tight');

# %%
df_est
# Out:
#           Date  SubwayTER  Subways: % of Comparable Pre-Pandemic Day   BusTER  \
# 0   2022-11-22    3548878                                      0.608  1236503
# 1   2022-11-21    3366444                                      0.588  1308734
# 2   2022-11-20    1720204                                      0.763   613770
# 3   2022-11-19    2320286                                      0.727   821154
# 4   2022-11-18    3539383                                      0.610  1354177
# ..         ...        ...                                        ...      ...
# 992 2020-03-05    5513656                                      0.956  2244500
# 993 2020-03-04    5515945                                      0.968  2177200
# 994 2020-03-03    5498556                                      0.961  2228600
# 995 2020-03-02    5347055                                      1.239  2209100
# 996 2020-03-01    2214601                                      0.987   984900
#
# ...

# %%
df_est.columns
# Out:
# Index(['Date', 'SubwayTER', 'Subways: % of Comparable Pre-Pandemic Day',
#        'BusTER', 'Buses: % of Comparable Pre-Pandemic Day', 'LIRRTER',
#        'LIRR: % of 2019 Monthly Weekday/Saturday/Sunday Average',
#        'MetroNorthTeR',
#        'Metro-North: % of 2019 Monthly Weekday/Saturday/Sunday Average',
#        'Access-A-Ride: Total Scheduled Trips',
#        'Access-A-Ride: % of Comprable Pre-Pandemic Day', 'Bridges_Tunnels_TT',
#        'Bridges and Tunnels: % of Comparable Pre-Pandemic Day'],
#       dtype='object')

# %%
df_est
# Out:
#           Date  SubwayTER  Subways: % of Comparable Pre-Pandemic Day   BusTER  \
# 0   2022-11-22    3548878                                      0.608  1236503
# 1   2022-11-21    3366444                                      0.588  1308734
# 2   2022-11-20    1720204                                      0.763   613770
# 3   2022-11-19    2320286                                      0.727   821154
# 4   2022-11-18    3539383                                      0.610  1354177
# ..         ...        ...                                        ...      ...
# 992 2020-03-05    5513656                                      0.956  2244500
# 993 2020-03-04    5515945                                      0.968  2177200
# 994 2020-03-03    5498556                                      0.961  2228600
# 995 2020-03-02    5347055                                      1.239  2209100
# 996 2020-03-01    2214601                                      0.987   984900
#
# ...

# %%
df_est.drop(["Buses: % of Comparable Pre-Pandemic Day","Metro-North: % of 2019 Monthly Weekday/Saturday/Sunday Average","Access-A-Ride: % of Comprable Pre-Pandemic Day","Bridges and Tunnels: % of Comparable Pre-Pandemic Day"],axis=1,inplace=True)

# %%
df_est.pop("LIRR: % of 2019 Monthly Weekday/Saturday/Sunday Average")
# Out:
# 0      0.69
# 1      0.64
# 2      0.80
# 3      0.87
# 4      0.61
#        ...
# 992     NaN
# 993     NaN
# 994     NaN
# 995     NaN
# 996     NaN
# Name: LIRR: % of 2019 Monthly Weekday/Saturday/Sunday Average, Length: 997, dtype: float64

# %%
df_est
# Out:
#           Date  SubwayTER  Subways: % of Comparable Pre-Pandemic Day   BusTER  \
# 0   2022-11-22    3548878                                      0.608  1236503
# 1   2022-11-21    3366444                                      0.588  1308734
# 2   2022-11-20    1720204                                      0.763   613770
# 3   2022-11-19    2320286                                      0.727   821154
# 4   2022-11-18    3539383                                      0.610  1354177
# ..         ...        ...                                        ...      ...
# 992 2020-03-05    5513656                                      0.956  2244500
# 993 2020-03-04    5515945                                      0.968  2177200
# 994 2020-03-03    5498556                                      0.961  2228600
# 995 2020-03-02    5347055                                      1.239  2209100
# 996 2020-03-01    2214601                                      0.987   984900
#
# ...

# %%
df_est_may=df_est.loc[(df_est.Date>="2022-05-01")&(df_est.Date<="2022-05-30")]

# %%
df_est_may
# Out:
#           Date  SubwayTER  Subways: % of Comparable Pre-Pandemic Day   BusTER  \
# 176 2022-05-30    1697221                                      0.652   755616
# 177 2022-05-29    1757512                                      0.693   701173
# 178 2022-05-28    1874966                                      0.591   788135
# 179 2022-05-27    3036867                                      0.527  1353398
# 180 2022-05-26    3347608                                      0.583  1464696
# 181 2022-05-25    3433392                                      0.603  1493506
# 182 2022-05-24    3385529                                      0.624  1488152
# 183 2022-05-23    3118111                                      0.558  1431781
# 184 2022-05-22    1762501                                      0.693   683500
# 185 2022-05-21    2326775                                      0.772   883795
# 186 2022-05-20    3277954                                      0.605  1396732
# ...

# %%
df_est_april=df_est.loc[(df_est.Date>="2022-04-01")&(df_est.Date<="2022-04-30")]
df_est_may=df_est.loc[(df_est.Date>="2022-05-01")&(df_est.Date<="2022-05-30")]
df_est_jun=df_est.loc[(df_est.Date>="2022-06-01")&(df_est.Date<="2022-06-17")]

# %%
df_est_april
# Out:
#           Date  SubwayTER  Subways: % of Comparable Pre-Pandemic Day   BusTER  \
# 206 2022-04-30    2110869                                      0.654   884540
# 207 2022-04-29    3263534                                      0.568  1429909
# 208 2022-04-28    3411703                                      0.578  1468093
# 209 2022-04-27    3439185                                      0.592  1500437
# 210 2022-04-26    3288681                                      0.571  1453452
# 211 2022-04-25    3032863                                      0.546  1415638
# 212 2022-04-24    1655863                                      0.684   648591
# 213 2022-04-23    2109247                                      0.645   844146
# 214 2022-04-22    2991024                                      0.592  1217380
# 215 2022-04-21    3039160                                      0.556  1231047
# 216 2022-04-20    3104143                                      0.571  1265823
# ...

# %%
df_ap_sum=pd.DataFrame(df_est_april,columns=["Date","LIRRTER","MetroNorthTeR"])
df_may_sum=pd.DataFrame(df_est_may,columns=["Date","LIRRTER","MetroNorthTeR"])
df_jun_sum=pd.DataFrame(df_est_jun,columns=["Date","LIRRTER","MetroNorthTeR"])

# %%
df_ap_sum["Total_Estimed_Riders"]=df_ap_sum["LIRRTER"]+df_ap_sum["MetroNorthTeR"]
df_ap_sum["Total_Estimed_Riders_APRIL"]=df_ap_sum["Total_Estimed_Riders"].sum()

df_may_sum["Total_Estimed_Riders"]=df_may_sum["LIRRTER"]+df_may_sum["MetroNorthTeR"]
df_may_sum["Total_Estimed_Riders_May"]=df_may_sum["Total_Estimed_Riders"].sum()

df_jun_sum["Total_Estimed_Riders"]=df_jun_sum["LIRRTER"]+df_jun_sum["MetroNorthTeR"]
df_jun_sum["Total_Estimed_Riders_Jun"]=df_jun_sum["Total_Estimed_Riders"].sum()

# %%
df_ap_sum
# Out:
#           Date   LIRRTER  MetroNorthTeR  Total_Estimed_Riders  \
# 206 2022-04-30   82900.0        82800.0              165700.0
# 207 2022-04-29  164900.0       136900.0              301800.0
# 208 2022-04-28  167300.0       146300.0              313600.0
# 209 2022-04-27  172600.0       153100.0              325700.0
# 210 2022-04-26  172200.0       153900.0              326100.0
# 211 2022-04-25  159600.0       139000.0              298600.0
# 212 2022-04-24   64800.0        67600.0              132400.0
# 213 2022-04-23   79400.0        89800.0              169200.0
# 214 2022-04-22  157900.0       145600.0              303500.0
# 215 2022-04-21  165800.0       147500.0              313300.0
# 216 2022-04-20  171700.0       155700.0              327400.0
# 217 2022-04-19  168400.0       151500.0              319900.0
# 218 2022-04-18  154300.0       139200.0              293500.0
# 219 2022-04-17   71300.0        71700.0              143000.0
# ...

# %%
df_may_sum
# Out:
#           Date   LIRRTER  MetroNorthTeR  Total_Estimed_Riders  \
# 176 2022-05-30   80500.0        68200.0              148700.0
# 177 2022-05-29   84800.0        77000.0              161800.0
# 178 2022-05-28   91300.0        77200.0              168500.0
# 179 2022-05-27  167800.0       135300.0              303100.0
# 180 2022-05-26  176500.0       148000.0              324500.0
# 181 2022-05-25  178100.0       158800.0              336900.0
# 182 2022-05-24  182600.0       163900.0              346500.0
# 183 2022-05-23  170500.0       151300.0              321800.0
# 184 2022-05-22   78600.0        72100.0              150700.0
# 185 2022-05-21   94300.0        92600.0              186900.0
# 186 2022-05-20  175700.0       146400.0              322100.0
# 187 2022-05-19  172500.0       150000.0              322500.0
# 188 2022-05-18  182200.0       161100.0              343300.0
# 189 2022-05-17  182700.0       162100.0              344800.0
# ...

# %%
df_jun_sum
# Out:
#           Date   LIRRTER  MetroNorthTeR  Total_Estimed_Riders  \
# 158 2022-06-17  187200.0       148600.0              335800.0
# 159 2022-06-16  190200.0       162500.0              352700.0
# 160 2022-06-15  192600.0       169500.0              362100.0
# 161 2022-06-14  191200.0       174300.0              365500.0
# 162 2022-06-13  174300.0       150400.0              324700.0
# 163 2022-06-12   80800.0        74600.0              155400.0
# 164 2022-06-11  117900.0        95100.0              213000.0
# 165 2022-06-10  187800.0       159200.0              347000.0
# 166 2022-06-09  179500.0       157500.0              337000.0
# 167 2022-06-08  181100.0       162400.0              343500.0
# 168 2022-06-07  185700.0       163800.0              349500.0
# 169 2022-06-06  167100.0       148200.0              315300.0
# 170 2022-06-05   75700.0        74000.0              149700.0
# 171 2022-06-04   93400.0        92200.0              185600.0
# ...

# %%
Estimated_Riders={"Months":["April","May","Until 15 June"],
                 "Total Estimated Riders LIRR and MetroNorth":[7813000,7951500,5124800]}
df_est_rdr=pd.DataFrame(Estimated_Riders,index=[0,1,2])

# %%
df_est_rdr
# Out:
#           Months  Total Estimated Riders LIRR and MetroNorth
# 0          April                                     7813000
# 1            May                                     7951500
# 2  Until 15 June                                     5124800

# %%
df_est_rdr["Total Estimated Riders LIRR and MetroNorth"].sum()
# Out:
# 20889300

# %%
def human_format(num, pos):
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.0f%s' % (num, ['', 'K', 'M', 'G', 'T', 'P'][magnitude])

# %%
sns.set_style("whitegrid")
sns.barplot(x=df_est_rdr["Months"],y=df_est_rdr["Total Estimated Riders LIRR and MetroNorth"])
plt.xlabel("Months")
plt.ylabel("Total Estimated Riders LIRR and MetroNorth")
plt.title("Estimated Ridership for LIRR and Metro North")
plt.savefig("graphs/est_rdr.png",bbox_inches='tight')
ax=sns.barplot(x=df_est_rdr["Months"],y=df_est_rdr["Total Estimated Riders LIRR and MetroNorth"])
ax.yaxis.set_major_formatter(FuncFormatter(human_format));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 grouped_df.plot(kind="bar", y="value")
#
# NameError: name 'grouped_df' is not defined

# %%
cencus = pd.read_excel('Census_data.xlsx')
cencus.dropna(axis = 1, inplace = True)
cencus.head()

# %%
cencus["Population"] = cencus["Population"].astype('int64')
cencus["FemalePercent"] = cencus["FemalePercent"].astype('float')
cencus["BachelorsDegreePercent"] = cencus["BachelorsDegreePercent"].astype('float')
cencus["MedianIncome"] = cencus["MedianIncome"].astype('int64')
cencus["TotalEmployer"] = cencus["TotalEmployer"].astype('int64')
cencus["TotalEmployment"] = cencus["TotalEmployment"].astype('int64')
cencus["AnnualPayroll"] = cencus["AnnualPayroll"].astype('int64')
cencus["AllFirms"] = cencus["AllFirms"].astype('int64')
cencus["WomenOwnedFirms"] = cencus["WomenOwnedFirms"].astype('int64')

# %%
import pandas as pd
import numpy as np
import dateutil.parser
import datetime
from datetime import datetime as dt
from datetime import time
from datetime import timedelta
from datetime import date
import calendar
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import seaborn as sns

# %%
from matplotlib.ticker import FuncFormatter
plt.figure(figsize=[20,17])
plt.style.use('default')


plt.suptitle('New York Borough Census Data',fontsize = 18, weight = "bold", c = "Black")

plt.subplot(3,3,1) 
ax = sns.barplot(x = "Borough", y = "Population", data = cencus, palette = 'flare')
plt.xlabel(""), plt.ylabel("")
ax.yaxis.set_major_formatter(FuncFormatter(human_format))
plt.title('Population', weight = "bold");

plt.subplot(3,3,2)
ax = sns.barplot(x = "Borough", y = "FemalePercent", data = cencus, palette = 'flare')
plt.xlabel(""), plt.ylabel("")
plt.title('Female Percent', weight = "bold");


plt.subplot(3,3,3) 
ax = sns.barplot(x="Borough", y="BachelorsDegreePercent", data=cencus, palette = 'flare')
plt.xlabel(""),plt.ylabel("")
plt.title('Bachelors Degree Percent', weight="bold");

plt.subplot(3,3,4) 
ax = sns.barplot(x = "Borough", y = "MedianIncome", data = cencus, palette = 'flare')
plt.xlabel(""),plt.ylabel("")
plt.title('Median Income', weight="bold");

plt.subplot(3,3,5) 
ax = sns.barplot(x = "Borough", y = "TotalEmployer", data = cencus, palette = 'flare')
plt.xlabel(""),plt.ylabel("")
plt.title('Total Employer', weight="bold");

plt.subplot(3,3,6) 
ax = sns.barplot(x = "Borough", y = "TotalEmployment", data = cencus, palette = 'flare')
plt.xlabel(""),plt.ylabel("")
ax.yaxis.set_major_formatter(FuncFormatter(human_format))
plt.title('Total Employment', weight="bold");

plt.subplot(3,3,7) 
ax = sns.barplot(x = "Borough", y = "AnnualPayroll", data = cencus, palette = 'flare')
plt.xlabel(""),plt.ylabel("")
ax.yaxis.set_major_formatter(FuncFormatter(human_format))
plt.title('Annual Payroll', weight="bold");

plt.subplot(3,3,8) 
ax = sns.barplot(x = "Borough", y = "AllFirms", data = cencus, palette = 'flare')
plt.xlabel(""),plt.ylabel("")
plt.title('All Firms', weight = "bold");

plt.subplot(3,3,9) 
ax = sns.barplot(x = "Borough", y = "WomenOwnedFirms", data = cencus, palette = 'flare')
plt.xlabel(""),plt.ylabel("")
plt.title('Women Owned Firms', weight = "bold");
